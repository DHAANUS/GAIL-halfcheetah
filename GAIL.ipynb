# %%
# Clean any old/conflicting stuff
# !pip uninstall -y mujoco-py || true

# Fresh toolchain
# !python -m pip install -U pip setuptools wheel

# Numeric stack pins (avoid NumPy 2 issues for RL libs)
# !pip install "numpy<2.0" "torch==2.2.*"

# MuJoCo + Gymnasium (modern IDs like HalfCheetah-v4)
# !pip install "mujoco==3.1.6" "gymnasium[mujoco]==0.29.1"

# RL stack
# !pip install "stable-baselines3==2.3.2" "imitation==1.0.1"

# Utils for logs + video
# !pip install tensorboard "imageio[ffmpeg]" moviepy
# Out:
# WARNING: Skipping mujoco-py as it is not installed.
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 79.0 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.9 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-25.2 setuptools-80.9.0
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting torch==2.2.*
#   Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.2.*) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.*)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.*)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.*)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.*)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.*)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.*)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.*)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.*)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.*)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.*)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.*)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.*) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.2.*) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.2.*) (1.3.0)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 211.4 MB/s  0:00:00
# Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 38.8 MB/s  0:00:10
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 59.6 MB/s  0:00:05
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 136.3 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 125.3 MB/s  0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.5 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 42.1 MB/s  0:00:10
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 81.6 MB/s  0:00:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 107.4 MB/s  0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 43.9 MB/s  0:00:02
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 65.7 MB/s  0:00:02
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 62.9 MB/s  0:00:02
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.2.2 which is incompatible.
# Successfully installed numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.2
# Collecting mujoco==3.1.6
#   Downloading mujoco-3.1.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting gymnasium==0.29.1 (from gymnasium[mujoco]==0.29.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.13.0)
# Collecting glfw (from mujoco==3.1.6)
#   Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.26.4)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (3.1.9)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (0.0.4)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]==0.29.1) (2.37.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]==0.29.1) (11.3.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (3.23.0)
# Downloading mujoco-3.1.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.7 MB/s  0:00:01
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 54.8 MB/s  0:00:00
# Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 107, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 98, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 71, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 452, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 588, in _determine_conflicts
# ^C

# %%
# 1) Remove the conflicting pair if partially installed
# !pip uninstall -y stable-baselines3 imitation

# 2) Install the mutually compatible versions together
# !pip install "stable-baselines3==2.2.1" "imitation==1.0.1"
# Out:
# WARNING: Skipping stable-baselines3 as it is not installed.
# WARNING: Skipping imitation as it is not installed.
# Collecting stable-baselines3==2.2.1
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting imitation==1.0.1
#   Using cached imitation-1.0.1-py3-none-any.whl.metadata (14 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3==2.2.1)
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.2.1) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.2.1) (2.2.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.2.1) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.2.1) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.2.1) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from imitation==1.0.1) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from imitation==1.0.1) (13.9.4)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from imitation==1.0.1) (1.6.1)
# Collecting seals~=0.2.1 (from imitation==1.0.1)
#   Using cached seals-0.2.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting sacred>=0.8.4 (from imitation==1.0.1)
#   Downloading sacred-0.8.7-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.12/dist-packages (from imitation==1.0.1) (2.19.0)
# Collecting huggingface-sb3~=3.0 (from imitation==1.0.1)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting optuna>=3.0.1 (from imitation==1.0.1)
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: datasets>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from imitation==1.0.1) (4.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.2.1) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.2.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[classic-control]~=0.29->imitation==1.0.1) (2.6.1)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.12/dist-packages (from huggingface-sb3~=3.0->imitation==1.0.1) (0.34.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-sb3~=3.0->imitation==1.0.1) (6.0.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface-sb3~=3.0->imitation==1.0.1) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (1.1.7)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.8.0->imitation==1.0.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.8.0->imitation==1.0.1) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.8.0->imitation==1.0.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.8.0->imitation==1.0.1) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.8.0->imitation==1.0.1) (3.10)
# Collecting alembic>=1.5.0 (from optuna>=3.0.1->imitation==1.0.1)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.0.1->imitation==1.0.1)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.1->imitation==1.0.1) (2.0.43)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.0.1->imitation==1.0.1) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3~=3.0->imitation==1.0.1) (2025.8.3)
# Collecting docopt-ng<1.0,>=0.9 (from sacred>=0.8.4->imitation==1.0.1)
#   Downloading docopt_ng-0.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jsonpickle>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from sacred>=0.8.4->imitation==1.0.1) (4.1.1)
# Collecting munch<5.0,>=2.5 (from sacred>=0.8.4->imitation==1.0.1)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: wrapt<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from sacred>=0.8.4->imitation==1.0.1) (1.17.3)
# Requirement already satisfied: py-cpuinfo>=4.0 in /usr/local/lib/python3.12/dist-packages (from sacred>=0.8.4->imitation==1.0.1) (9.0.0)
# Collecting colorama>=0.4 (from sacred>=0.8.4->imitation==1.0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from sacred>=0.8.4->imitation==1.0.1) (3.1.45)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.2->imitation==1.0.1) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.2->imitation==1.0.1) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.2->imitation==1.0.1) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0.1->imitation==1.0.1) (3.2.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (80.9.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->imitation==1.0.1) (3.1.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3==2.2.1) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.14->imitation==1.0.1) (3.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->sacred>=0.8.4->imitation==1.0.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->sacred>=0.8.4->imitation==1.0.1) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.2.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.2.1) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->imitation==1.0.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->imitation==1.0.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->imitation==1.0.1) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.13->stable-baselines3==2.2.1) (1.3.0)
# Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
# Downloading imitation-1.0.1-py3-none-any.whl (216 kB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading seals-0.2.1-py3-none-any.whl (35 kB)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Downloading sacred-0.8.7-py2.py3-none-any.whl (108 kB)
# Downloading docopt_ng-0.9.0-py3-none-any.whl (16 kB)
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: munch, gymnasium, docopt-ng, colorlog, colorama, seals, alembic, sacred, optuna, huggingface-sb3, stable-baselines3, imitation
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.0
#     Uninstalling gymnasium-1.2.0:
#       Successfully uninstalled gymnasium-1.2.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [imitation]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed alembic-1.16.4 colorama-0.4.6 colorlog-6.9.0 docopt-ng-0.9.0 gymnasium-0.29.1 huggingface-sb3-3.0 imitation-1.0.1 munch-4.0.0 optuna-4.5.0 sacred-0.8.7 seals-0.2.1 stable-baselines3-2.2.1

# %%
# Remove legacy gym + a package that forces a conflicting gymnasium
# !pip uninstall -y gym dopamine-rl

# Reinstall MuJoCo + Gymnasium with the MuJoCo extras
# !pip install -U "mujoco==3.1.6" "gymnasium[mujoco]==0.29.1"
# Out:
# Found existing installation: gym 0.25.2
# Uninstalling gym-0.25.2:
#   Successfully uninstalled gym-0.25.2
# Found existing installation: dopamine_rl 4.1.2
# Uninstalling dopamine_rl-4.1.2:
#   Successfully uninstalled dopamine_rl-4.1.2
# Collecting mujoco==3.1.6
#   Using cached mujoco-3.1.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]==0.29.1) (0.29.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.13.0)
# Collecting glfw (from mujoco==3.1.6)
#   Using cached glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (1.26.4)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco==3.1.6) (3.1.9)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1->gymnasium[mujoco]==0.29.1) (0.0.4)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]==0.29.1) (2.37.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]==0.29.1) (11.3.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.1.6) (3.23.0)
# Using cached mujoco-3.1.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Using cached glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
# Installing collected packages: glfw, mujoco
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [mujoco]
# Successfully installed glfw-2.9.0 mujoco-3.1.6

# %%
pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)

# %%
pip install --upgrade --force-reinstall --no-cache-dir "numpy==2.1.1"
# Out:
# Collecting numpy==2.1.1
#   Downloading numpy-2.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Downloading numpy-2.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 94.2 MB/s  0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.2.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.1 which is incompatible.
# Successfully installed numpy-2.1.1

# %%
import os
os.environ["MUJOCO_GL"] = "egl"  # set before any gym/mujoco imports

import gymnasium as gym, mujoco
print("MuJoCo:", mujoco.__version__)
env = gym.make("HalfCheetah-v4")
env.reset()
env.close()
print("Env OK")
# Out:
# MuJoCo: 3.1.6
# Env OK

# %%
import gymnasium as gym, stable_baselines3 as sb3, imitation
print("SB3:", sb3.__version__)
print("imitation:", imitation.__version__)
env = gym.make("HalfCheetah-v4")
print("OK:", env.observation_space.shape, env.action_space.shape)
env.close()
# Out:
# SB3: 2.2.1
# imitation: 1.0.1
# OK: (17,) (6,)

# %%
# !pip install -q "imageio[ffmpeg]" moviepy

# %%
# %%writefile gail_mujoco.py
#!/usr/bin/env python3
import os
import argparse
import numpy as np
from pathlib import Path

os.environ.setdefault("MUJOCO_GL", "egl")
from imitation.util.networks import RunningNorm

import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import VecNormalize, VecVideoRecorder
from imitation.util.util import make_vec_env as imit_make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.data import rollout, serialize
from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm

RUNS = Path("runs")
MODELS = RUNS / "models"
DEMOS = RUNS / "demos"
VIDEOS = RUNS / "videos"
STATS = RUNS / "venv_stats"
for p in [RUNS, MODELS, DEMOS, VIDEOS, STATS]:
    p.mkdir(parents=True, exist_ok=True)


def make_env(env_id: str, n_envs: int, seed: int, render_rgb=False):
    env_kwargs = {"render_mode": "rgb_array"} if render_rgb else {}
    venv = imit_make_vec_env(
        env_id,
        rng=np.random.default_rng(seed),
        n_envs=n_envs,
        env_make_kwargs=env_kwargs,
        post_wrappers=[lambda env, _: RolloutInfoWrapper(env)],
    )
    venv = VecNormalize(venv, norm_obs=True, norm_reward=False, clip_obs=10.0)
    return venv

from pathlib import Path

def _resolve_model_path(env_id: str, which: str) -> Path:
    name = f"{env_id}_{'ppo_expert' if which=='expert' else 'gail_policy'}"
    candidates = [
        MODELS / f"{name}.zip",
        MODELS / name,
    ]
    for c in candidates:
        if c.exists():
            return c if c.suffix == ".zip" else (c.with_suffix(".zip") if (c.with_suffix(".zip")).exists() else c)
    hits = list(MODELS.glob(f"{name}*.zip"))
    if hits:
        return hits[0]
    raise FileNotFoundError(f"Model not found: looked for {candidates} and {name}*.zip")

def train_expert(env_id: str, total_steps: int, seed: int, tb_tag: str):
    venv = make_env(env_id, n_envs=8, seed=seed)
    model = PPO(
        policy=MlpPolicy,
        env=venv,
        n_steps=2048,
        batch_size=64,
        learning_rate=3e-4,
        ent_coef=0.0,
        gamma=0.99,
        gae_lambda=0.95,
        n_epochs=10,
        verbose=1,
        seed=seed,
        tensorboard_log=str(RUNS),
    )
    model.learn(total_timesteps=total_steps, tb_log_name=f"{tb_tag}_expert")
    model.save(MODELS / f"{env_id}_ppo_expert.zip")
    venv.save(STATS / f"{env_id}_expert_vecnorm.pkl")
    venv.close()

def collect_demos(env_id: str, min_steps: int, min_episodes: int, seed: int):
    venv = make_env(env_id, n_envs=8, seed=seed)
    venv = VecNormalize.load(STATS / f"{env_id}_expert_vecnorm.pkl", venv)
    venv.training = False
    expert = PPO.load(MODELS / f"{env_id}_ppo_expert.zip", env=venv)

    sample_until = rollout.make_sample_until(
        min_timesteps=min_steps if min_steps else None,
        min_episodes=min_episodes if min_episodes else None,
    )
    demos = rollout.rollout(
        expert,
        venv,
        sample_until=sample_until,
        rng=np.random.default_rng(seed),
    )
    serialize.save(DEMOS / f"{env_id}_expert_trajs", demos)
    venv.close()

# def train_gail(env_id: str, total_steps: int, seed: int, tb_tag: str):
#     venv = make_env(env_id, n_envs=8, seed=seed)
#     # learner = PPO(
#     #     policy=MlpPolicy,
#     #     env=venv,
#     #     batch_size=64,
#     #     learning_rate=4e-4,
#     #     gamma=0.95,
#     #     n_epochs=5,
#     #     ent_coef=0.0,
#     #     seed=seed,
#     #     tensorboard_log=str(RUNS),
#     #     verbose=1,
#     # )
#     learner = PPO(
#           policy=MlpPolicy,
#           env=venv,
#           batch_size=256,        # was 64
#           n_steps=2048,          # longer rollouts help IL
#           n_epochs=10,           # was 5
#           learning_rate=3e-4,    # slightly smaller than 4e-4
#           gamma=0.99,            # back to standard
#           ent_coef=0.01,         # encourage exploration
#           seed=seed,
#           tensorboard_log=str(RUNS),
#           verbose=1,
#       )
#     demos = serialize.load(DEMOS / f"{env_id}_expert_trajs")

#     reward_net = BasicRewardNet(
#         observation_space=venv.observation_space,
#         action_space=venv.action_space,
#         normalize_input_layer=RunningNorm,
#     )

#     # gail = GAIL(
#     #     demonstrations=demos,
#     #     demo_batch_size=1024,
#     #     gen_replay_buffer_capacity=10_000,
#     #     n_disc_updates_per_round=8,
#     #     venv=venv,
#     #     gen_algo=learner,
#     #     reward_net=reward_net,
#     # )
#     gail = GAIL(
#     demonstrations=demos,
#     demo_batch_size=256,           # was 1024
#     gen_replay_buffer_capacity=50_000,
#     n_disc_updates_per_round=2,    # was 8 (too many -> saturation)
#     venv=venv,
#     gen_algo=learner,
#     reward_net=reward_net,
#     )

#     pre_mean, pre_std = evaluate_policy(learner, venv, n_eval_episodes=5, return_episode_rewards=False)
#     print(f"[GAIL] pre-train eval return ~ {pre_mean:.2f} ± {pre_std:.2f}")

#     gail.train(total_timesteps=total_steps)


#     learner.save(MODELS / f"{env_id}_gail_policy.zip")
#     venv.save(STATS / f"{env_id}_gail_vecnorm.pkl")
#     venv.close()
def train_gail(env_id: str, total_steps: int, seed: int, tb_tag: str):
    """
    GAIL training that:
      - uses the SAME VecNormalize stats as the expert (frozen) to avoid scaling mismatch,
      - weakens the discriminator so it doesn't saturate,
      - strengthens PPO a bit with more exploration,
      - optionally warm-starts the policy with BC (version-agnostic).
    """
    # --- 1) Env with expert VecNormalize stats (frozen) ---
    venv = make_env(env_id, n_envs=8, seed=seed)
    expert_stats = STATS / f"{env_id}_expert_vecnorm.pkl"
    if expert_stats.exists():
        venv = VecNormalize.load(expert_stats, venv)
        venv.training = False   # freeze stats to match demos
    else:
        print(f"[WARN] Missing expert stats at {expert_stats}; GAIL may be unstable")

    # --- 2) PPO generator: steadier updates + a bit more exploration ---
    policy_kwargs = dict(log_std_init=-2.0)  # helps reduce early action spikes
    learner = PPO(
        policy=MlpPolicy,
        env=venv,
        n_steps=2048,
        batch_size=256,
        n_epochs=10,
        learning_rate=3e-4,
        gamma=0.99,
        ent_coef=0.01,
        seed=seed,
        tensorboard_log=str(RUNS),
        verbose=1,
        policy_kwargs=policy_kwargs,
    )

    # --- 3) Load expert demos ---
    demos = serialize.load(DEMOS / f"{env_id}_expert_trajs")

    # --- 4) Smaller, smoother discriminator (avoid instant 99% acc) ---
    from torch import nn
    reward_net = BasicRewardNet(
        observation_space=venv.observation_space,
        action_space=venv.action_space,
        normalize_input_layer=RunningNorm,
        hid_sizes=(64,),         # downsize capacity
        activation=nn.Tanh,      # smoother than ReLU
    )

    gail = GAIL(
        demonstrations=demos,
        demo_batch_size=256,               # was 1024 → reduce
        gen_replay_buffer_capacity=50_000, # larger buffer
        n_disc_updates_per_round=1,        # was 8 → avoid saturation
        venv=venv,
        gen_algo=learner,
        reward_net=reward_net,
    )

    # --- 5) (Optional) BC warm-start, robust across imitation versions ---
    try:
        from imitation.algorithms import bc as bc_mod
        from imitation.data import types as types_mod

        def trajs_to_transitions(trajs):
            # Use library helper if present
            if hasattr(types_mod, "trajectories_to_transitions"):
                return types_mod.trajectories_to_transitions(trajs)
            # Manual conversion (older/newer versions)
            TransitionsCls = getattr(types_mod, "Transitions", None) or getattr(types_mod, "TransitionsMinimal", None)
            if TransitionsCls is None:
                raise RuntimeError("imitation.data.types missing a Transitions class")

            obs_list, acts_list, next_obs_list, dones_list = [], [], [], []
            for t in trajs:
                o = t.obs            # (T+1, obs_dim)
                a = t.acts           # (T, act_dim)
                term = getattr(t, "terminal", None)
                if term is not None:
                    d = np.zeros(len(a), dtype=bool); d[-1] = bool(term)
                else:
                    d_attr = getattr(t, "dones", None)
                    if d_attr is None:
                        d = np.zeros(len(a), dtype=bool); d[-1] = True
                    else:
                        d = np.asarray(d_attr, dtype=bool)
                obs_list.append(o[:-1]); acts_list.append(a); next_obs_list.append(o[1:]); dones_list.append(d)

            obs = np.concatenate(obs_list)
            acts = np.concatenate(acts_list)
            next_obs = np.concatenate(next_obs_list)
            dones = np.concatenate(dones_list)
            try:
                return TransitionsCls(obs=obs, acts=acts, next_obs=next_obs, dones=dones, infos=None)
            except TypeError:
                return TransitionsCls(obs=obs, acts=acts, next_obs=next_obs, dones=dones)

        transitions = trajs_to_transitions(demos)
        bc = bc_mod.BC(
            observation_space=venv.observation_space,
            action_space=venv.action_space,
            demonstrations=transitions,
            policy=learner.policy,   # warm-start the SAME policy PPO will use
        )
        bc.train(n_epochs=5)
        print("[BC] Warm-start complete (5 epochs).")
    except Exception as e:
        print(f"[BC] Skipping warm-start: {e}")

    # --- 6) Sanity check on wrapped eval (not true env reward) ---
    pre_mean, pre_std = evaluate_policy(learner, venv, n_eval_episodes=5, return_episode_rewards=False)
    print(f"[GAIL] pre-train eval (wrapped) ~ {pre_mean:.2f} ± {pre_std:.2f}")

    # --- 7) Train GAIL ---
    gail.train(total_timesteps=total_steps)

    # --- 8) Save policy + the (frozen) stats we trained with ---
    learner.save(MODELS / f"{env_id}_gail_policy.zip")
    venv.save(STATS / f"{env_id}_gail_vecnorm.pkl")
    venv.close()


def evaluate(env_id: str, which: str, episodes: int, seed: int, video_len: int):
    render_env = make_env(env_id, n_envs=1, seed=seed, render_rgb=True)

    # Attach saved normalization stats if present
    stats_file = STATS / f"{env_id}_{which}_vecnorm.pkl"
    if stats_file.exists():
        render_env = VecNormalize.load(stats_file, render_env)

    # Freeze stats and report TRUE env rewards
    if isinstance(render_env, VecNormalize):
        render_env.training = False
        render_env.norm_reward = False

    model_path = _resolve_model_path(env_id, which)
    model = PPO.load(model_path, env=render_env)

    mean_r, std_r = evaluate_policy(model, render_env, n_eval_episodes=episodes, return_episode_rewards=False)
    print(f"[{which.upper()}] eval return (TRUE reward) ~ {mean_r:.2f} ± {std_r:.2f} over {episodes} episodes")

    video_env = VecVideoRecorder(
        render_env,
        video_folder=str(Path("runs") / "videos"),
        record_video_trigger=lambda step: step == 0,
        video_length=video_len,
        name_prefix=f"{env_id}_{which}",
    )
    obs = video_env.reset()      # no [0]
    t = 0
    while t < video_len:
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = video_env.step(action)  # 4 returns for VecEnv
        if dones[0]:
            obs = video_env.reset()
        t += 1
    video_env.close()
    render_env.close()

def main():
    parser = argparse.ArgumentParser()
    sub = parser.add_subparsers(dest="cmd", required=True)

    parser.add_argument("--env-id", type=str, default="HalfCheetah-v4")
    parser.add_argument("--seed", type=int, default=42)

    p_exp = sub.add_parser("expert")
    p_exp.add_argument("--steps", type=int, default=800_000)
    p_exp.add_argument("--tb-tag", type=str, default="expert")

    p_dem = sub.add_parser("demos")
    p_dem.add_argument("--min-steps", type=int, default=200_000)
    p_dem.add_argument("--min-episodes", type=int, default=0)

    p_gail = sub.add_parser("gail")
    p_gail.add_argument("--steps", type=int, default=800_000)
    p_gail.add_argument("--tb-tag", type=str, default="gail")

    p_eval = sub.add_parser("eval")
    p_eval.add_argument("--which", type=str, choices=["expert", "gail"], default="gail")
    p_eval.add_argument("--episodes", type=int, default=10)
    p_eval.add_argument("--video-len", type=int, default=1000)

    args = parser.parse_args()

    if args.cmd == "expert":
        train_expert(args.env_id, args.steps, args.seed, args.tb_tag)
    elif args.cmd == "demos":
        collect_demos(args.env_id, args.min_steps, args.min_episodes, args.seed)
    elif args.cmd == "gail":
        train_gail(args.env_id, args.steps, args.seed, args.tb_tag)
    elif args.cmd == "eval":
        evaluate(args.env_id, args.which, args.episodes, args.seed, args.video_len)

if __name__ == "__main__":
    main()
# Out:
# Overwriting gail_mujoco.py

# %%
import os
os.environ["MUJOCO_GL"] = "egl"

# %%
# !pip uninstall -y numpy
# !pip install "numpy<2.0"
# Out:
# Found existing installation: numpy 2.1.1
# Uninstalling numpy-2.1.1:
#   Successfully uninstalled numpy-2.1.1
# Collecting numpy<2.0
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.2.2 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import numpy, torch
print("NumPy:", numpy.__version__)
print("Torch:", torch.__version__)
# Out:
# NumPy: 1.26.4
# Torch: 2.2.2+cu121

# %%
import gymnasium as gym, mujoco
print("MuJoCo OK:", mujoco.__version__)
env = gym.make("HalfCheetah-v4"); obs,_ = env.reset(); print(obs.shape); env.close()
# Out:
# MuJoCo OK: 3.1.6
# (17,)

# %%
rm -rf runs/*

# %%
# 0) (Optional) headless rendering
# export MUJOCO_GL=egl

# 1) Train PPO expert
# !python gail_mujoco.py --env-id HalfCheetah-v4 expert --steps 800000

# 2) Collect expert demos
# !python gail_mujoco.py --env-id HalfCheetah-v4 demos --min-steps 200000

# 3) Train GAIL
# !python gail_mujoco.py --env-id HalfCheetah-v4 gail --steps 800000

# 4) Evaluate + record a video
# !python gail_mujoco.py --env-id HalfCheetah-v4 eval --which gail --episodes 10 --video-len 1000
# Out:
# 2025-08-20 08:39:05.697383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755679145.718305   39892 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755679145.724444   39892 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755679145.740126   39892 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679145.740158   39892 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679145.740162   39892 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679145.740165   39892 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Using cuda device
# Logging to runs/expert_expert_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -363     |
# | time/              |          |
# |    fps             | 3675     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007933157 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | -0.0145     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 0.988       |
# |    value_loss           | 26.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 1458        |
# |    iterations           | 3           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008684507 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00828    |
# |    std                  | 0.978       |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 4           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008956941 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.34       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00913    |
# |    std                  | 0.971       |
# |    value_loss           | 31.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -312        |
# | time/                   |             |
# |    fps                  | 1298        |
# |    iterations           | 5           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008794844 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.961       |
# |    value_loss           | 24.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 6           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009328274 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.22       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.67        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00922    |
# |    std                  | 0.951       |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -295        |
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 7           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008085575 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.17       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.945       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 8           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009822035 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.35        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.936       |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 9           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010835726 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.06       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.927       |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -241        |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 10          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.010655079 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.914       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -226        |
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 11          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.011326675 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.91        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.904       |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -204        |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 12          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.012290005 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.86       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.895       |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 13          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.013400129 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.85        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.881       |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 14          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.013080534 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.96        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.871       |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 1178        |
# |    iterations           | 15          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.012925103 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.52        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.861       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 16          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.015766408 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.58        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.85        |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -82        |
# | time/                   |            |
# |    fps                  | 1171       |
# |    iterations           | 17         |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.01459332 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.47      |
# |    explained_variance   | 0.631      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.09       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0169    |
# |    std                  | 0.84       |
# |    value_loss           | 11         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -55.1      |
# | time/                   |            |
# |    fps                  | 1168       |
# |    iterations           | 18         |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.01575154 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.596      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.32       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0188    |
# |    std                  | 0.829      |
# |    value_loss           | 13.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -24.6      |
# | time/                   |            |
# |    fps                  | 1166       |
# |    iterations           | 19         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.01552841 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.31      |
# |    explained_variance   | 0.451      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.41       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0173    |
# |    std                  | 0.817      |
# |    value_loss           | 15.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 20          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.016258013 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.24       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.81        |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 62.6        |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 21          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.016513903 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.17       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.799       |
# |    value_loss           | 12.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 96.6        |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 22          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.016785841 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.5         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.789       |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 23          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.017078357 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.01       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.57        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.779       |
# |    value_loss           | 12.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 1158       |
# |    iterations           | 24         |
# |    time_elapsed         | 339        |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.01837008 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.94      |
# |    explained_variance   | 0.369      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.51       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0198    |
# |    std                  | 0.769      |
# |    value_loss           | 14.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 25          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.018715333 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.85       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.23        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.757       |
# |    value_loss           | 14.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 26          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.017825685 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.69        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.75        |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 27          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.019833606 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.68       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.737       |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 325         |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 28          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.019684844 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.58       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.93        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.726       |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 368         |
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 29          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.021786418 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.48       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.67        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.713       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 417         |
# | time/                   |             |
# |    fps                  | 1151        |
# |    iterations           | 30          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.021719217 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.38       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.46        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.702       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 462         |
# | time/                   |             |
# |    fps                  | 1149        |
# |    iterations           | 31          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.020385705 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.25       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.03        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.688       |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 506         |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 32          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.021450324 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.16       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.678       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 549         |
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 33          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.020960614 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.06       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.8         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.667       |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 589         |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 34          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.021734677 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.97       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.69        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.657       |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 625         |
# | time/                   |             |
# |    fps                  | 1144        |
# |    iterations           | 35          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.019592017 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.9        |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.55        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.649       |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 658         |
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 36          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.022278253 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.641       |
# |    value_loss           | 16.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 697         |
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 37          |
# |    time_elapsed         | 530         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.021706045 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.92        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.632       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 730         |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 38          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.023087446 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.16        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.623       |
# |    value_loss           | 17.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 760         |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 39          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.022506999 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.52        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.614       |
# |    value_loss           | 15          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 795         |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 40          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.022461407 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.606       |
# |    value_loss           | 14          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 834        |
# | time/                   |            |
# |    fps                  | 1140       |
# |    iterations           | 41         |
# |    time_elapsed         | 589        |
# |    total_timesteps      | 671744     |
# | train/                  |            |
# |    approx_kl            | 0.02187321 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.37      |
# |    explained_variance   | 0.649      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.63       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0138    |
# |    std                  | 0.6        |
# |    value_loss           | 15.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 892         |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 42          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.022440016 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.95        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.591       |
# |    value_loss           | 12.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 927        |
# | time/                   |            |
# |    fps                  | 1139       |
# |    iterations           | 43         |
# |    time_elapsed         | 618        |
# |    total_timesteps      | 704512     |
# | train/                  |            |
# |    approx_kl            | 0.02536581 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.18      |
# |    explained_variance   | 0.642      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.84       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0152    |
# |    std                  | 0.58       |
# |    value_loss           | 14.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 958         |
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 44          |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.021480983 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.04        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.573       |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 993         |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 45          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.025755515 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.52        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.567       |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 46          |
# |    time_elapsed         | 662         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.022939844 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.56        |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 47          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.025322385 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.61        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.552       |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 48          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.023208221 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.93        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.545       |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 49          |
# |    time_elapsed         | 705         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.025381383 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.538       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# 2025-08-20 08:51:10.672917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755679870.692493   42874 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755679870.698498   42874 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755679870.713790   42874 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679870.713818   42874 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679870.713821   42874 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755679870.713823   42874 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Saving the dataset (1/1 shards): 100% 200/200 [00:00<00:00, 7668.74 examples/s]
# 2025-08-20 08:52:10.038898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755679930.058670   43153 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
# |    gen/train/explained_variance     | 0.785    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 0.376    |
# |    gen/train/n_updates              | 440      |
# |    gen/train/policy_gradient_loss   | -0.0125  |
# |    gen/train/std                    | 0.161    |
# |    gen/train/value_loss             | 0.85     |
# --------------------------------------------------
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 1e+03       |
# |    gen/rollout/ep_rew_mean         | 64.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 536         |
# |    gen/time/fps                    | 2716        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 737280      |
# |    gen/train/approx_kl             | 0.023086604 |
# |    gen/train/clip_fraction         | 0.259       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | 2.45        |
# |    gen/train/explained_variance    | 0.785       |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 0.376       |
# |    gen/train/n_updates             | 440         |
# |    gen/train/policy_gradient_loss  | -0.0125     |
# |    gen/train/std                   | 0.161       |
# |    gen/train/value_loss            | 0.85        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.834    |
# |    disc/disc_acc_expert             | 0.848    |
# |    disc/disc_acc_gen                | 0.82     |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.514    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 45       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.834    |
# |    disc/disc_acc_expert             | 0.848    |
# |    disc/disc_acc_gen                | 0.82     |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.514    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 45       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# |    gen/rollout/ep_len_mean          | 1e+03    |
# |    gen/rollout/ep_rew_mean          | 64.3     |
# |    gen/rollout/ep_rew_wrapped_mean  | 536      |
# |    gen/time/fps                     | 2.72e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 7.37e+05 |
# |    gen/train/approx_kl              | 0.023    |
# |    gen/train/clip_fraction          | 0.258    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | 2.39     |
# |    gen/train/explained_variance     | 0.85     |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 0.584    |
# |    gen/train/n_updates              | 450      |
# |    gen/train/policy_gradient_loss   | -0.0172  |
# |    gen/train/std                    | 0.163    |
# |    gen/train/value_loss             | 1.13     |
# --------------------------------------------------
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 1e+03       |
# |    gen/rollout/ep_rew_mean         | 62.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 534         |
# |    gen/time/fps                    | 2691        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 753664      |
# |    gen/train/approx_kl             | 0.022986058 |
# |    gen/train/clip_fraction         | 0.258       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | 2.39        |
# |    gen/train/explained_variance    | 0.85        |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 0.584       |
# |    gen/train/n_updates             | 450         |
# |    gen/train/policy_gradient_loss  | -0.0172     |
# |    gen/train/std                   | 0.163       |
# |    gen/train/value_loss            | 1.13        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.84     |
# |    disc/disc_acc_expert             | 0.871    |
# |    disc/disc_acc_gen                | 0.809    |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.515    |
# |    disc/disc_proportion_expert_pred | 0.531    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 46       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.84     |
# |    disc/disc_acc_expert             | 0.871    |
# |    disc/disc_acc_gen                | 0.809    |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.515    |
# |    disc/disc_proportion_expert_pred | 0.531    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 46       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# |    gen/rollout/ep_len_mean          | 1e+03    |
# |    gen/rollout/ep_rew_mean          | 62.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 534      |
# |    gen/time/fps                     | 2.69e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 7.54e+05 |
# |    gen/train/approx_kl              | 0.025    |
# |    gen/train/clip_fraction          | 0.28     |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | 2.33     |
# |    gen/train/explained_variance     | 0.871    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 0.632    |
# |    gen/train/n_updates              | 460      |
# |    gen/train/policy_gradient_loss   | -0.0243  |
# |    gen/train/std                    | 0.165    |
# |    gen/train/value_loss             | 1.54     |
# --------------------------------------------------
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 1e+03       |
# |    gen/rollout/ep_rew_mean         | 57.8        |
# |    gen/rollout/ep_rew_wrapped_mean | 540         |
# |    gen/time/fps                    | 2670        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 770048      |
# |    gen/train/approx_kl             | 0.024959538 |
# |    gen/train/clip_fraction         | 0.28        |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | 2.33        |
# |    gen/train/explained_variance    | 0.871       |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 0.632       |
# |    gen/train/n_updates             | 460         |
# |    gen/train/policy_gradient_loss  | -0.0243     |
# |    gen/train/std                   | 0.165       |
# |    gen/train/value_loss            | 1.54        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.838    |
# |    disc/disc_acc_expert             | 0.887    |
# |    disc/disc_acc_gen                | 0.789    |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.549    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.838    |
# |    disc/disc_acc_expert             | 0.887    |
# |    disc/disc_acc_gen                | 0.789    |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.549    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 47       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# |    gen/rollout/ep_len_mean          | 1e+03    |
# |    gen/rollout/ep_rew_mean          | 57.8     |
# |    gen/rollout/ep_rew_wrapped_mean  | 540      |
# |    gen/time/fps                     | 2.67e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 7.7e+05  |
# |    gen/train/approx_kl              | 0.0254   |
# |    gen/train/clip_fraction          | 0.303    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | 2.27     |
# |    gen/train/explained_variance     | 0.774    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 1.04     |
# |    gen/train/n_updates              | 470      |
# |    gen/train/policy_gradient_loss   | -0.0287  |
# |    gen/train/std                    | 0.166    |
# |    gen/train/value_loss             | 2.28     |
# --------------------------------------------------
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 1e+03       |
# |    gen/rollout/ep_rew_mean         | 52.4        |
# |    gen/rollout/ep_rew_wrapped_mean | 549         |
# |    gen/time/fps                    | 2705        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 786432      |
# |    gen/train/approx_kl             | 0.025401365 |
# |    gen/train/clip_fraction         | 0.303       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | 2.27        |
# |    gen/train/explained_variance    | 0.774       |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 1.04        |
# |    gen/train/n_updates             | 470         |
# |    gen/train/policy_gradient_loss  | -0.0287     |
# |    gen/train/std                   | 0.166       |
# |    gen/train/value_loss            | 2.28        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.791    |
# |    disc/disc_acc_expert             | 0.871    |
# |    disc/disc_acc_gen                | 0.711    |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.521    |
# |    disc/disc_proportion_expert_pred | 0.58     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.791    |
# |    disc/disc_acc_expert             | 0.871    |
# |    disc/disc_acc_gen                | 0.711    |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.521    |
# |    disc/disc_proportion_expert_pred | 0.58     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 256      |
# |    disc/n_generated                 | 256      |
# |    gen/rollout/ep_len_mean          | 1e+03    |
# |    gen/rollout/ep_rew_mean          | 52.4     |
# |    gen/rollout/ep_rew_wrapped_mean  | 549      |
# |    gen/time/fps                     | 2.7e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 7.86e+05 |
# |    gen/train/approx_kl              | 0.0282   |
# |    gen/train/clip_fraction          | 0.327    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | 2.25     |
# |    gen/train/explained_variance     | 0.682    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 1.01     |
# |    gen/train/n_updates              | 480      |
# |    gen/train/policy_gradient_loss   | -0.0301  |
# |    gen/train/std                    | 0.167    |
# |    gen/train/value_loss             | 2.37     |
# --------------------------------------------------
# round: 100% 48/48 [07:01<00:00,  8.78s/it]
# 2025-08-20 08:59:29.842574: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755680369.862609   44987 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755680369.868693   44987 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755680369.883919   44987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755680369.883945   44987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755680369.883948   44987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755680369.883950   44987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [GAIL] eval return (TRUE reward) ~ 68.08 ± 31.21 over 10 episodes
# Saving video to /content/runs/videos/HalfCheetah-v4_gail-step-0-to-step-1000.mp4
# Moviepy - Building video /content/runs/videos/HalfCheetah-v4_gail-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/runs/videos/HalfCheetah-v4_gail-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/runs/videos/HalfCheetah-v4_gail-step-0-to-step-1000.mp4
# Moviepy - Building video /content/runs/videos/HalfCheetah-v4_gail-step-1000-to-step-2000.mp4.
# Moviepy - Writing video /content/runs/videos/HalfCheetah-v4_gail-step-1000-to-step-2000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/runs/videos/HalfCheetah-v4_gail-step-1000-to-step-2000.mp4

# %%
import shutil, os, datetime
name = f"runs_{datetime.date.today().isoformat()}"  # e.g. runs_2025-08-20
archive_path = shutil.make_archive(name, "zip", root_dir="runs")  # creates runs_YYYY-MM-DD.zip in CWD
print("Created:", archive_path, os.path.getsize(archive_path)/1e6, "MB")

from google.colab import files
files.download(archive_path)
# Out:
# Created: /content/runs_2025-08-20.zip 35.033258 MB
